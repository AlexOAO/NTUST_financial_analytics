# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# 載入紅酒資料集
wine = load_wine()

# 將資料分成訓練集和測試集
X_train, X_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.4, random_state=1)

# %%
#檢視X
import pandas as pd
X_train_df = pd.DataFrame(X_train, columns=wine.feature_names)
X_train_df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    13.58        2.58  2.69               24.5      105.0           1.55
# 1    13.27        4.28  2.26               20.0      120.0           1.59
# 2    12.77        3.43  1.98               16.0       80.0           1.63
# 3    11.66        1.88  1.92               16.0       97.0           1.61
# 4    12.93        3.80  2.65               18.6      102.0           2.41
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        0.84                  0.39             1.54             8.66  0.74
# 1        0.69                  0.43             1.35            10.20  0.59
# 2        1.25                  0.43             0.83             3.40  0.70
# 3        1.57                  0.34             1.15             3.80  1.23
# 4        2.41                  0.25             1.98             4.50  1.03
#
#    od280/od315_of_diluted_wines  proline
# 0                          1.80    750.0
# 1                          1.56    835.0
# 2                          2.12    372.0
# 3                          2.14    428.0
# 4                          3.52    770.0

# %%
#檢視y
y_train_df = pd.DataFrame(y_train, columns=["target"])
y_train_df.head()
# Out:
#    target
# 0       2
# 1       2
# 2       1
# 3       1
# 4       0

# %%
#建立決策樹模型

DT = DecisionTreeClassifier()

# 使用訓練資料進行訓練
DT.fit(X_train, y_train)

# 使用測試集預測紅酒類別
y_pred = DT.predict(X_test)

# 評估模型準確度
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9305555555555556

# %%
#畫圖
from sklearn import tree
tree.plot_tree(DT)
# Out:
# [Text(0.4444444444444444, 0.9375, 'x[12] <= 938.0\ngini = 0.657\nsamples = 106\nvalue = [31, 44, 31]'),
#  Text(0.3333333333333333, 0.8125, 'x[6] <= 0.975\ngini = 0.543\nsamples = 80\nvalue = [5, 44, 31]'),
#  Text(0.2222222222222222, 0.6875, 'gini = 0.0\nsamples = 25\nvalue = [0, 0, 25]'),
#  Text(0.4444444444444444, 0.6875, 'x[11] <= 1.505\ngini = 0.34\nsamples = 55\nvalue = [5, 44, 6]'),
#  Text(0.3333333333333333, 0.5625, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5]'),
#  Text(0.5555555555555556, 0.5625, 'x[12] <= 760.0\ngini = 0.215\nsamples = 50\nvalue = [5, 44, 1]'),
#  Text(0.3333333333333333, 0.4375, 'x[9] <= 9.5\ngini = 0.088\nsamples = 44\nvalue = [1, 42, 1]'),
#  Text(0.2222222222222222, 0.3125, 'x[1] <= 3.925\ngini = 0.045\nsamples = 43\nvalue = [1, 42, 0]'),
#  Text(0.1111111111111111, 0.1875, 'gini = 0.0\nsamples = 40\nvalue = [0, 40, 0]'),
#  Text(0.3333333333333333, 0.1875, 'x[7] <= 0.37\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.2222222222222222, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.4444444444444444, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.4444444444444444, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7777777777777778, 0.4375, 'x[1] <= 1.62\ngini = 0.444\nsamples = 6\nvalue = [4, 2, 0]'),
#  Text(0.6666666666666666, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8888888888888888, 0.3125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.5555555555555556, 0.8125, 'gini = 0.0\nsamples = 26\nvalue = [26, 0, 0]')]
